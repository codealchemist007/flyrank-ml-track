# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/codealchemist007/week1_assignment1/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# I'm going with Lane 2: Refresh / Content Opportunity Scoring. This is mainly because I already saw this lane basically working in the starter notebooks - there's a baseline score and then a model that beats it by a good margin (0.740
# precision@50 vs 0.240 for the plain rules). So I'm not starting from
# scratch, I already know that this direction works.
#
# The thing I want to improve on is the label the starter uses right now -
# it just checks if a page is currently trending down, which is kind of a
# weak signal since it's only looking at "right now". I want to try building
# toward a label that actually looks ahead, like whether a page is going to
# decline in the next 30 days, since that's a stronger and more useful thing
# to predict than just its current state.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# The decision: Out of all the pages a client has, which ones should a content reviewer actually look at first? Right now that's kind of a guessing game or based on gut feel, so the idea is to give them a ranked list instead - pages sorted by how urgently they need review, with a reason attached for why each one made the list.
#
# The action: A reviewer only has time to check a limited number of pages, so they'd go down this ranked list and act on the top ones first - maybe rewriting them, updating content or just flagging them for a deeper look.
#
# The cost of a wrong call: If I flag a page that's actually fine as urgent, that's wasted reviewer time on something that didn't need it. But if I miss a page that's genuinely declining, it just keeps losing traffic quietly with nobody noticing until it's a bigger problem. So the ranking has to actually be trustworthy, not just look busy.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*
#
# Looking at the starter dataset:
#
# - 16,262 of 30,000 pages (54.2%) are currently marked as declining
# - Of those, 13,152 pages have real traffic behind them (impressions_90d >= 100),
#   so this isn't just noise from tiny, barely-visited pages
# - Those at-risk pages together account for close to 80 million impressions,
#   which is a lot of real visibility that could be slipping away unnoticed
#
# This backs up why Lane 2 seems worth building on - there's clearly a large
# volume of pages that could use review and enough real traffic at stake that
# getting the prioritization right actually matters.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# !git clone https://github.com/codealchemist007/week1_assignment1.git

import pandas as pd

df = pd.read_csv("week1_assignment1/data/raw/content_refresh_anonymized.csv")

# Number 1: how many pages are currently in a declining state
declining_count = (df["trend_direction"] == "down").sum()
total_count = len(df)
print(f"{declining_count} of {total_count} pages are currently declining ({declining_count/total_count:.1%})")

# Number 2: how many of those declining pages actually have meaningful traffic (not noise)
at_risk = df[(df["trend_direction"] == "down") & (df["impressions_90d"] >= 100)]
print(f"{len(at_risk)} pages are declining AND have meaningful impressions (>=100) - real opportunity, not noise")

# Number 3: how much visibility (impressions) is sitting in at-risk pages
total_at_risk_impressions = at_risk["impressions_90d"].sum()
print(f"Those at-risk pages account for {total_at_risk_impressions:,.0f} total impressions - real traffic worth protecting")
# Out:
# fatal: destination path 'week1_assignment1' already exists and is not an empty directory.
# 16262 of 30000 pages are currently declining (54.2%)
# 13152 pages are declining AND have meaningful impressions (>=100) - real opportunity, not noise
# Those at-risk pages account for 79,887,612 total impressions - real traffic worth protecting

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# What I can say: I can claim that this work can rank pages by observed signals - which ones show real, measurable decline, backed by enough traffic to matter. That's useful for helping a reviewer prioritize where to spend their limited time.
#
# What I can't say: I can't claim that refreshing or rewriting a flagged page
# will actually cause it to recover - that would need an actual experiment,
# not just historical data. I also can't claim anything about how Google's
# algorithm works, or that a page's decline was "caused" by anything specific
# just from this data. Everything here is observed and directional, not proof
# of cause and effect.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [x] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [x] No client names, URLs, or private queries anywhere
# - [x] My claims use careful words: observed, measured, directional, decision-support
# - [x] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
